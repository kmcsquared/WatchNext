# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np

from fetching_ratings import get_user_ratings
from app_functions import unzip_and_load_datasets, normalise_scores

# %% [markdown]
# ## Loading Data

# %% [markdown]
# ### My Ratings

# %%
df_my_ratings = get_user_ratings()
df_my_ratings
# Out:
# Retrieving ratings from page 1/3
# Content retrieved: 100
#
# Retrieving ratings from page 2/3
# Content retrieved: 200
#
# Retrieving ratings from page 3/3
# Content retrieved: 261
#          tconst  userRating
# 0    tt16968450           4
# 1     tt1517268           5
# 2    tt10478048           7
# 3    tt14230458           7
# 4    tt17351924           6
# ..          ...         ...
# 256   tt7366338           8
# 257   tt2707408           9
# 258   tt0111161          10
# 259   tt0944947           9
# 260   tt0903747          10
#
# [261 rows x 2 columns]

# %% [markdown]
# ### IMDB Data

# %%
datasets = unzip_and_load_datasets()

# %%
# Get series and episode data
df_imdb_titles = datasets[0]
df_imdb_titles = df_imdb_titles.loc[~(df_imdb_titles['titleType'].isin(['tvSeries', 'tvMiniSeries', 'tvEpisode']))]
num_non_series = len(df_imdb_titles)
print('# NON-SERIES:', num_non_series)

# Get ratings for series and episodes
df_imdb_ratings = datasets[1]
df_imdb_titles = df_imdb_titles.merge(df_imdb_ratings, on='tconst')
num_non_series_with_ratings = len(df_imdb_titles)
print('# NON-SERIES WITH RATINGS: {} ({}%)'.format(num_non_series_with_ratings, round(100*num_non_series_with_ratings / num_non_series)))

df_imdb_titles['titleType'].value_counts()
# Out:
# # NON-SERIES: 2174181
# # NON-SERIES WITH RATINGS: 595750 (27%)
# movie        305312
# short        155504
# video         52440
# tvMovie       52282
# videoGame     15871
# tvSpecial     12070
# tvShort        2271
# Name: titleType, dtype: int64

# %% [markdown]
# # Steps
# - Rank films by score (combination of number of votes and series ratings)
# - Rank films by runtime

# %% [markdown]
# ## Score

# %%
df_score = df_imdb_titles.copy()
df_score['score'] = df_score['averageRating'] * df_score['numVotes']
df_score = normalise_scores(df_score, score_col='score')
df_score['scoreRank'] = df_score['score'].rank(method='min', ascending=False).astype(int) # Ranks 1,2,2,4,5,6,6,8 style
df_score.sort_values('scoreRank', inplace=True)
df_score.head()
# Out:
#            tconst titleType                                   primaryTitle  \
# 76240   tt0111161     movie                       The Shawshank Redemption
# 44707   tt0068646     movie                                  The Godfather
# 221173  tt0468569     movie                                The Dark Knight
# 104883  tt0167260     movie  The Lord of the Rings: The Return of the King
# 74028   tt0108052     movie                               Schindler's List
#
#                                         originalTitle isAdult startYear  \
# 76240                        The Shawshank Redemption       0      1994
# 44707                                   The Godfather       0      1972
# 221173                                The Dark Knight       0      2008
# 104883  The Lord of the Rings: The Return of the King       0      2003
# 74028                                Schindler's List       0      1993
#
#        endYear runtimeMinutes                   genres  averageRating  \
# 76240       \N            142                    Drama            9.3
# 44707       \N            175              Crime,Drama            9.2
# 221173      \N            152       Action,Crime,Drama            9.0
# 104883      \N            201   Action,Adventure,Drama            9.0
# 74028       \N            195  Biography,Drama,History            9.0
#
#         numVotes  score  scoreRank
# 76240    2855595   9.65          1
# 44707    1989468   9.59          2
# 221173   2836667   9.50          3
# 104883   1956052   9.49          4
# 74028    1434395   9.46          5

# %% [markdown]
# # Finished and Unwatched

# %%
from datetime import datetime

df_watch = df_score.loc[~(df_score['tconst'].isin(df_my_ratings['tconst']))]
df_watch.index = np.arange(1, 1+len(df_watch))
df_watch.to_csv('df_nonseries_watch.csv')
df_watch.head(20)
# Out:
#         tconst titleType                                  primaryTitle  \
# 1    tt0078748     movie                                         Alien
# 2    tt0245429     movie                                 Spirited Away
# 3    tt0253474     movie                                   The Pianist
# 4    tt0317248     movie                                   City of God
# 5    tt0118799     movie                             Life Is Beautiful
# 6    tt0086250     movie                                      Scarface
# 7    tt0066921     movie                            A Clockwork Orange
# 8    tt0095016     movie                                      Die Hard
# 9    tt0075314     movie                                   Taxi Driver
# 10   tt0198781     movie                                Monsters, Inc.
# 11   tt0054215     movie                                        Psycho
# 12   tt0090605     movie                                        Aliens
# 13   tt1201607     movie  Harry Potter and the Deathly Hallows: Part 2
# 14  tt10872600     movie                       Spider-Man: No Way Home
# 15   tt0211915     movie                                        Amélie
# 16   tt0093058     movie                             Full Metal Jacket
# 17   tt0078788     movie                                Apocalypse Now
# 18   tt0118715     movie                              The Big Lebowski
# 19   tt3315342     movie                                         Logan
# 20   tt0083658     movie                                  Blade Runner
#
#                                     originalTitle isAdult startYear endYear  \
# 1                                           Alien       0      1979      \N
# 2                   Sen to Chihiro no kamikakushi       0      2001      \N
# 3                                     The Pianist       0      2002      \N
# 4                                  Cidade de Deus       0      2002      \N
# 5                                 La vita è bella       0      1997      \N
# 6                                        Scarface       0      1983      \N
# 7                              A Clockwork Orange       0      1971      \N
# 8                                        Die Hard       0      1988      \N
# 9                                     Taxi Driver       0      1976      \N
# 10                                 Monsters, Inc.       0      2001      \N
# 11                                         Psycho       0      1960      \N
# 12                                         Aliens       0      1986      \N
# 13  Harry Potter and the Deathly Hallows - Part 2       0      2011      \N
# 14                        Spider-Man: No Way Home       0      2021      \N
# 15            Le fabuleux destin d'Amélie Poulain       0      2001      \N
# 16                              Full Metal Jacket       0      1987      \N
# 17                                 Apocalypse Now       0      1979      \N
# 18                               The Big Lebowski       0      1998      \N
# 19                                          Logan       0      2017      \N
# 20                                   Blade Runner       0      1982      \N
#
#    runtimeMinutes                      genres  averageRating  numVotes  score  \
# 1             117               Horror,Sci-Fi            8.5    939284   9.01
# 2             125  Adventure,Animation,Family            8.6    835663   8.99
# 3             150       Biography,Drama,Music            8.5    900366   8.98
# 4             130                 Crime,Drama            8.6    793764   8.94
# 5             116        Comedy,Drama,Romance            8.6    735923   8.88
# 6             170                 Crime,Drama            8.3    905700   8.87
# 7             136                Crime,Sci-Fi            8.3    873847   8.84
# 8             132             Action,Thriller            8.2    937500   8.84
# 9             114                 Crime,Drama            8.2    908784   8.82
# 10             92  Adventure,Animation,Comedy            8.1    968317   8.80
# 11            109     Horror,Mystery,Thriller            8.5    711749   8.79
# 12            137     Action,Adventure,Sci-Fi            8.4    755705   8.78
# 13            130    Adventure,Family,Fantasy            8.1    937904   8.78
# 14            148    Action,Adventure,Fantasy            8.2    861971   8.77
# 15            122              Comedy,Romance            8.3    788820   8.76
# 16            116                   Drama,War            8.3    782937   8.75
# 17            147           Drama,Mystery,War            8.4    703383   8.71
# 18            117                Comedy,Crime            8.1    853132   8.70
# 19            137         Action,Drama,Sci-Fi            8.1    820134   8.67
# 20            117         Action,Drama,Sci-Fi            8.1    814807   8.67
#
#     scoreRank
# 1        48.0
# 2        54.0
# 3        56.0
# 4        64.0
# 5        72.0
# 6        73.0
# 7        81.0
# 8        81.0
# 9        85.0
# 10       87.0
# 11       88.0
# 12       89.0
# 13       89.0
# 14       91.0
# 15       93.0
# 16       95.0
# 17       98.0
# 18       99.0
# 19      101.0
# 20      101.0
